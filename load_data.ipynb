# %%
import requests
import pandas as pd

URL ='http://api.hh.ru/vacancies?area=1&text=Product&search_field=name'
df=pd.DataFrame()
for i in range(20):
    df = df.append(pd.DataFrame(requests.get(URL.format(str(i))).json()['items']))
# Out:
# /var/folders/jl/lsn73r2d50l0m4vgv43dgjbm0000gn/T/ipykernel_74934/1534159628.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(requests.get(URL.format(str(i))).json()['items']))
# /var/folders/jl/lsn73r2d50l0m4vgv43dgjbm0000gn/T/ipykernel_74934/1534159628.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(requests.get(URL.format(str(i))).json()['items']))
# /var/folders/jl/lsn73r2d50l0m4vgv43dgjbm0000gn/T/ipykernel_74934/1534159628.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(requests.get(URL.format(str(i))).json()['items']))
# ...

# %%
df.to_csv(r'/Users/dimka/Desktop/проект/load_data.csv', index = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 19
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         400 non-null    object
#  1   premium                    400 non-null    bool
#  2   name                       400 non-null    object
#  3   department                 20 non-null     object
#  4   has_test                   400 non-null    bool
#  5   response_letter_required   400 non-null    bool
#  6   area                       400 non-null    object
#  7   salary                     180 non-null    object
#  8   type                       400 non-null    object
#  9   address                    240 non-null    object
#  10  response_url               0 non-null      object
#  11  sort_point_distance        0 non-null      object
#  12  published_at               400 non-null    object
# ...

# %%
df.drop(columns=['department', 'has_test', 'response_url', 'relations', 'working_days', 'working_time_intervals', 'working_time_modes', 'type', 'address', 'sort_point_distance', 'created_at', 'archived', 'apply_alternate_url', 'show_logo_in_search', 'insider_interview', 'url', 'alternate_url', 'snippet', 'contacts', 'accept_temporary', 'accept_incomplete_resumes', 'adv_response_url', 'response_letter_required', 'is_adv_vacancy', 'adv_context', 'branding'], inplace = True)

# %%
import numpy as np
df['salary'] = np.random.randint (100000 , 250000 ,size=( 400 , 1))

# %%
df["premium"] = df['premium'].astype('int64')
df.dtypes
# Out:
# id                    object
# premium                int64
# name                  object
# area                  object
# salary                 int64
# published_at          object
# employer              object
# schedule              object
# professional_roles    object
# experience            object
# employment            object
# dtype: object

# %%
df["premium"] = df['premium']. replace(['False', 'True'], [0,1])

# %%
df["experience"] = df['experience'].astype('str')
df['start_year'] = df['experience'].str.extract('(\d+)')

# %%
#df['employment'] = df['employment'].apply(lambda x: x['name'])
#df['area'] = df['area'].apply(lambda x: x['name'])
#df['employer'] = df['employer'].apply(lambda x: x['name'])
#df['professional_roles'] = df['professional_roles'].apply(lambda x: x['name'])
df['schedule'] = df['schedule'].apply(lambda x: x['name'])

# %%
df
# Out:
#           id  premium                               name    area  salary  \
# 0   90646228        0             Junior Product Manager  Москва  127840
# 1   90504793        0             Стажер Product Manager  Москва  131101
# 2   90005929        0             Junior Product Manager  Москва  134932
# 3   90472971        0             Junior Product manager  Москва  166715
# 4   90110864        0                   Product менеджер  Москва  232552
# ..       ...      ...                                ...     ...     ...
# 15  91083126        0               Lead Product Manager  Москва  119459
# 16  90981138        0  Project Manager / Product Manager  Москва  114021
# 17  91047518        0  Product Designer (UX/UI дизайнер)  Москва  233660
# 18  90203602        0             Junior Product Analyst  Москва  151178
# 19  90464648        0                    Product manager  Москва  154779
#
#                 published_at                     employer          schedule  \
# ...

# %%
df['published_at'] = pd.to_datetime(df['published_at'])
df['published_at'] = df['published_at'].dt.strftime('%d-%m-%Y')

# %%
df["professional_roles"] = df['professional_roles'].astype('str')
df['professional_roles'] = df['professional_roles'].str.extract('(\d+)')

# %%
df.to_csv(r'/Users/dimka/Desktop/проект/load_data.csv', index = False)

# %%
df["start_year"] = df['start_year'].astype('float')
df['start_year'] = df['start_year'].fillna(method='ffill')
df.drop(columns=['experience'], inplace = True)

# %%
df
# Out:
#           id  premium                               name    area  salary  \
# 0   90646228        0             Junior Product Manager  Москва  127840
# 1   90504793        0             Стажер Product Manager  Москва  131101
# 2   90005929        0             Junior Product Manager  Москва  134932
# 3   90472971        0             Junior Product manager  Москва  166715
# 4   90110864        0                   Product менеджер  Москва  232552
# ..       ...      ...                                ...     ...     ...
# 15  91083126        0               Lead Product Manager  Москва  119459
# 16  90981138        0  Project Manager / Product Manager  Москва  114021
# 17  91047518        0  Product Designer (UX/UI дизайнер)  Москва  233660
# 18  90203602        0             Junior Product Analyst  Москва  151178
# 19  90464648        0                    Product manager  Москва  154779
#
#    published_at                     employer          schedule  \
# ...

# %%
#Cпособ №1 Сделать хеш мд5
#Способ №2 значение ассоциативного массива, прибавляю +1 для значения нового массива при появлении нового элемента
#Вставляем вместо индекса в асоциативный массив. СТолбец нужно добавить, нельзя заменить или удалить.

# %%
X = df.drop('salary', axis=1)
y = df['salary']

num_splits = 5

for i in range(num_splits):
   X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=i)
   X, y = X_test, y_test
print (X_test)
# Out:
#           id  premium                                               name  \
# 9   90802974        0              Data/Product Analyst (Стажер/Trainee)
# 14  91055192        0          Менеджер продукта / Product Manager (B2B)
# 13  90493308        0                   Junior Product Manager (GameDev)
# 19  90464648        0                                    Product manager
# 14  91055192        0          Менеджер продукта / Product Manager (B2B)
# 6   90343248        0                            Junior product designer
# 16  90981138        0                  Project Manager / Product Manager
# 12  90390258        0  Менеджер по продукту (Удаленно) / Product mana...
# 5   91069010        0        Middle React developer [EP Product Catalog]
# 0   90646228        0                             Junior Product Manager
# 13  90493308        0                   Junior Product Manager (GameDev)
# 13  90493308        0                   Junior Product Manager (GameDev)
# ...

# %%
df.to_csv(r'/Users/dimka/Desktop/проект/my_data.csv', index = False)

# %%
df.dtypes
# Out:
# id                     object
# premium                 int64
# name                   object
# area                   object
# salary                  int64
# published_at           object
# employer               object
# schedule               object
# professional_roles     object
# employment             object
# start_year            float64
# dtype: object
